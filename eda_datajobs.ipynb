# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Data Jobs Datasets

# %% [markdown]
# Data main source is Kaggle. I downloaded two webscraped and partly clean datasets uploaded by community members. Dataset contains data jobs posted on ai-jobs.net in the period of 2020 to 2022. Links down below:
# * [Data Jobs Source Link 1](https://www.kaggle.com/datasets/saurabhshahane/data-science-jobs-salaries)
# * [Data Jobs Source Link 2](https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Raw Datasets/DataScience_JobsSalaries.csv')
df1 = pd.read_csv('./Raw Datasets/DataScience_JobsSalaries1.csv')

# %%
df
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df1
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# Drop Unnamed column
df1.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        245 non-null    int64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
# Changing work_year dtype
df1.work_year = df1.work_year.astype('str')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    object
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 52.3+ KB

# %% [markdown]
# ## Joining datasets

# %%
df_ds = pd.concat([df,df1],axis=0)

# %%
df_ds['work_year'].value_counts()
# Out:
# 2022     318
# 2021     217
# 2021e    179
# 2020     138
# Name: work_year, dtype: int64

# %%
df_ds['work_year'] = df_ds['work_year'].str.strip('e')

# %%
df_ds['work_year'].value_counts()
# Out:
# 2021    396
# 2022    318
# 2020    138
# Name: work_year, dtype: int64

# %%
df_ds
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0        2021               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2        2021               EX              FT       Head of Data Science
# 3        2021               EX              FT               Head of Data
# 4        2021               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 602      2022               SE              FT              Data Engineer
# 603      2022               SE              FT              Data Engineer
# 604      2022               SE              FT               Data Analyst
# 605      2022               SE              FT               Data Analyst
# 606      2022               MI              FT               AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# ## NaN values and duplicates

# %%
df_ds.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df_ds.duplicated().sum()
# Out:
# 200

# %%
df_ds.drop_duplicates(inplace=True)

# %%
df_ds.sort_values(by=['work_year','job_title'], inplace=True)

# %%
df_ds.reset_index(inplace=True,drop=True)

# %%
df_ds.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df_ds = df_ds[['work_year','job_title','employment_type','experience_level','salary_in_usd','remote_ratio','employee_residence','company_location','company_size']]

# %% [markdown]
# ## Fixing values

# %% [markdown]
# Employment Type:
# * PT Part-time
# * FT Full-time
# * CT Contract
# * FL Freelance

# %%
df_ds.employment_type.value_counts()
# Out:
# FT    630
# PT     13
# CT      5
# FL      4
# Name: employment_type, dtype: int64

# %%
employment_type = {
    'PT': 'Part-time',
    'FT': 'Full-time',
    'CT': 'Contract',
    'FL': 'Freelance'
}

# %%
# Replacing employment_type categories
for find, repl in employment_type.items():
    df_ds.employment_type = df_ds.employment_type.str.replace(find, repl)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_10776\66707514.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds.employment_type = df_ds.employment_type.str.replace(find, repl)

# %%
df_ds.employment_type.value_counts()
# Out:
# Full-time    630
# Part-time     13
# Contract       5
# Freelance      4
# Name: employment_type, dtype: int64

# %% [markdown]
# Experience Level:
# * EN Entry-level / Junior
# * MI Mid-level / Intermediate
# * SE Senior-level / Expert
# * EX Executive-level / Director

# %%
df_ds.experience_level.value_counts()
# Out:
# SE    269
# MI    249
# EN    105
# EX     29
# Name: experience_level, dtype: int64

# %%
experience_level = {
    'EN': 'Junior',
    'MI': 'Semi-Senior',
    'SE': 'Senior',
    'EX': 'Executive'
}

# %%
# Replacing experience_level categories
for find, repl in experience_level.items():
    df_ds.experience_level = df_ds.experience_level.str.replace(find, repl)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_10776\922262886.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds.experience_level = df_ds.experience_level.str.replace(find, repl)

# %% [markdown]
# Company Size:
# * S: Small (0-50 employees)
# * M: Medium (50-250 employees)
# * L: Large (more than 250 employees)

# %%
df_ds.company_size.value_counts()
# Out:
# M    311
# L    243
# S     98
# Name: company_size, dtype: int64

# %%
company_size = {
    'S': 'Small',
    'M': 'Medium',
    'L': 'Large',
}

# %%
# Replacing company_size categories
for find, repl in company_size.items():
    df_ds.company_size = df_ds.company_size.str.replace(find, repl)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_10776\2193806173.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds.company_size = df_ds.company_size.str.replace(find, repl)

# %%
df_ds
# Out:
#     work_year                 job_title employment_type experience_level  \
# 0        2020              AI Scientist       Full-time           Junior
# 1        2020           BI Data Analyst       Full-time      Semi-Senior
# 2        2020         Big Data Engineer       Full-time           Senior
# 3        2020         Big Data Engineer       Full-time           Senior
# 4        2020         Big Data Engineer       Full-time           Junior
# ..        ...                       ...             ...              ...
# 647      2022  Principal Data Scientist       Full-time           Senior
# 648      2022        Research Scientist       Full-time           Senior
# 649      2022        Research Scientist       Full-time           Senior
# 650      2022        Research Scientist       Full-time      Semi-Senior
# 651      2022        Research Scientist       Full-time           Junior
#
#      salary_in_usd  remote_ratio employee_residence company_location  \
# ...

# %%
list(set(df_ds.job_title.values))
# Out:
# ['Data Science Manager',
#  'Machine Learning Manager',
#  'Big Data Engineer',
#  'Principal Data Analyst',
#  'Staff Data Scientist',
#  'ETL Developer',
#  '3D Computer Vision Researcher',
#  'Business Data Analyst',
#  'Data Scientist',
#  'Lead Data Analyst',
#  'Big Data Architect',
#  'Machine Learning Developer',
#  'Computer Vision Software Engineer',
#  'Lead Data Engineer',
#  'Data Architect',
#  'Marketing Data Analyst',
#  'Principal Data Scientist',
#  'Financial Data Analyst',
#  'Data Engineering Manager',
#  'Head of Data',
#  'NLP Engineer',
#  'ML Engineer',
#  'Lead Data Scientist',
#  'Principal Data Engineer',
#  'Director of Data Engineering',
#  'Data Engineer',
#  'Director of Data Science',
#  'Machine Learning Engineer',
#  'Data Science Engineer',
#  'Applied Machine Learning Scientist',
#  'Machine Learning Scientist',
#  'Machine Learning Infrastructure Engineer',
#  'Data Analytics Engineer',
#  'BI Data Analyst',
#  'Data Science Consultant',
# ...

# %%
df_ds.job_title.value_counts()
# Out:
# Data Scientist                              154
# Data Engineer                               135
# Data Analyst                                 86
# Machine Learning Engineer                    47
# Research Scientist                           22
# Data Science Manager                         14
# Big Data Engineer                            11
# Data Science Consultant                      11
# Data Architect                               11
# Director of Data Science                      9
# AI Scientist                                  8
# Computer Vision Engineer                      8
# Principal Data Scientist                      8
# Machine Learning Scientist                    8
# BI Data Analyst                               7
# Data Analytics Manager                        7
# Lead Data Engineer                            7
# ML Engineer                                   6
# Applied Data Scientist                        6
# Business Data Analyst                         6
# ...

# %% [markdown]
# ## Countries Dataset

# %% [markdown]
# Dataset was obtained from a collaborative Github repository. It contains alpha-2 code that let me to join with Data jobs dataset and bring the country name and region for the analysis.
# - [Countries Source Link](https://github.com/lukes/ISO-3166-Countries-with-Regional-Codes/blob/master/all/all.csv)

# %%
df_country = pd.read_csv('./countries.csv')

# %%
df_country
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
# ...

# %%
df_country.isna().sum()
# Out:
# name                          0
# alpha-2                       1
# alpha-3                       0
# country-code                  0
# iso_3166-2                    0
# region                        1
# sub-region                    1
# intermediate-region         142
# region-code                   1
# sub-region-code               1
# intermediate-region-code    142
# dtype: int64

# %% [markdown]
# Just interested in country name, alpha-2 and country code and region

# %%
df_country = df_country[['name', 'alpha-2', 'country-code','region']]

# %%
df_country.rename({'name':'country_name', 'alpha-2':'alpha_code','country-code':'num_code'}, inplace=True, axis=1)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_10776\4205312814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country.rename({'name':'country_name', 'alpha-2':'alpha_code','country-code':'num_code'}, inplace=True, axis=1)

# %%
df_country
# Out:
#           country_name alpha_code  num_code   region
# 0          Afghanistan         AF         4     Asia
# 1        Åland Islands         AX       248   Europe
# 2              Albania         AL         8   Europe
# 3              Algeria         DZ        12   Africa
# 4       American Samoa         AS        16  Oceania
# ..                 ...        ...       ...      ...
# 244  Wallis and Futuna         WF       876  Oceania
# 245     Western Sahara         EH       732   Africa
# 246              Yemen         YE       887     Asia
# 247             Zambia         ZM       894   Africa
# 248           Zimbabwe         ZW       716   Africa
#
# [249 rows x 4 columns]

# %% [markdown]
# * Verifying df_ds and df_country merge

# %%
df_country.to_csv('Clean Datasets/Countries_Dataset.csv', index=False)

# %%
df_ds1 = df_ds.merge(df_country[['alpha_code','country_name']], left_on='employee_residence', right_on='alpha_code')

# %%
df_ds1
# Out:
#     work_year                  job_title employment_type experience_level  \
# 0        2020               AI Scientist       Full-time           Junior
# 1        2021   Computer Vision Engineer       Part-time           Junior
# 2        2021   Computer Vision Engineer       Part-time           Junior
# 3        2020            BI Data Analyst       Full-time      Semi-Senior
# 4        2020          Big Data Engineer       Full-time           Junior
# ..        ...                        ...             ...              ...
# 647      2022             Data Scientist       Part-time           Junior
# 648      2022             Data Scientist       Full-time      Semi-Senior
# 649      2022               Head of Data       Full-time           Senior
# 650      2022               Head of Data       Full-time      Semi-Senior
# 651      2022  Machine Learning Engineer       Full-time           Senior
#
#      salary_in_usd  remote_ratio employee_residence company_location  \
# ...

# %% [markdown]
# ## Output dataframe

# %%
df_ds
# Out:
#     work_year                 job_title employment_type experience_level  \
# 0        2020              AI Scientist       Full-time           Junior
# 1        2020           BI Data Analyst       Full-time      Semi-Senior
# 2        2020         Big Data Engineer       Full-time           Senior
# 3        2020         Big Data Engineer       Full-time           Senior
# 4        2020         Big Data Engineer       Full-time           Junior
# ..        ...                       ...             ...              ...
# 647      2022  Principal Data Scientist       Full-time           Senior
# 648      2022        Research Scientist       Full-time           Senior
# 649      2022        Research Scientist       Full-time           Senior
# 650      2022        Research Scientist       Full-time      Semi-Senior
# 651      2022        Research Scientist       Full-time           Junior
#
#      salary_in_usd  remote_ratio employee_residence company_location  \
# ...

# %%
df_ds.to_csv('Clean Datasets/DataJobSalaries_Dataset.csv', index=False)
